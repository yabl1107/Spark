# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('test').getOrCreate()

# %%
sc = spark.sparkContext

# %%
df = spark.createDataFrame([(1,12),(2,29),(3,94)],['id','valor'])

# %% [markdown]
# Guardar el DataFrame en memoria y/o disco después de su primera evaluación, para que las siguientes operaciones sobre él no tengan que recalcularlo desde cero

# %%
df.show()
# Out:
# +---+-----+
# | id|valor|
# +---+-----+
# |  1|   12|
# |  2|   29|
# |  3|   94|
# +---+-----+

# %%
df.persist()
# Out:
# DataFrame[id: bigint, valor: bigint]

# %%
df.unpersist()
# Out:
# DataFrame[id: bigint, valor: bigint]

# %% [markdown]
# cache es como guardar con persis en storage level memory only

# %%
df.cache()
# Out:
# DataFrame[id: bigint, valor: bigint]

# %%
from pyspark.storagelevel import StorageLevel

# %%
df.persist(StorageLevel.DISK_ONLY)
# Out:
# DataFrame[id: bigint, valor: bigint]

# %%
df.persist(StorageLevel.MEMORY_AND_DISK)
# Out:
# DataFrame[id: bigint, valor: bigint]
